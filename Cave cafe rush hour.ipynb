# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\administrator\anaconda3\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\administrator\anaconda3\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.6.15)
# Requirement already satisfied: hstspreload in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\administrator\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\administrator\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\administrator\anaconda3\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\administrator\anaconda3\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
df=pd.read_excel("F:/Work/Revelio/Cave Cafe/cave_eng.xlsx")

# %% [markdown]
# ### EDA

# %%
print(df.columns)
# Out:
# Index(['Id', 'No', 'Barcode', 'Name', 'PriceList', 'Category_Id',
#        'category_name', 'Quantity', 'TotalPrice', 'Count', 'Client_Id', 'type',
#        'is_refund', 'Session_Id', 'User_Id', 'SalaCaptinId', 'DeliveryManId',
#        'BranchId', 'IsDeleted', 'TableId', 'DailyCount', 'YearCount',
#        'Is_Cash', 'Date', 'UnitId', 'ProductUnitName',
#        'QuantityFromParentForProductUnit', 'SoldUnitName',
#        'QuantityFromParentForSoldUnit', 'TotalCost', 'UnitCost', 'MenuId',
#        'IsDone', 'DiscountValue', 'StartSession', 'name_en',
#        'category_name_en'],
#       dtype='object')

# %%
from googletrans import Translator
translator = Translator()
def translate_text(text, dest_language='en'):
    try:
        return translator.translate(text,src='ar',dest='en').text
    except :
        return text
df['name_en'] = df['Name'].apply(translate_text)

# %%
df['category_name_en'] = df['category_name'].apply(translate_text)

# %%
df['name_en']
# Out:
# 0          Turkish coffee
# 1       Nescafe with milk
# 2             Small water
# 3           French coffee
# 4       Nescafe with milk
#               ...
# 4776                Pepsi
# 4777             Add mint
# 4778          Small water
# 4779       Turkish coffee
# 4780          Small water
# Name: name_en, Length: 4781, dtype: object

# %%
df= pd.read_excel("F:/Work/Revelio/Cave Cafe/CaveCafe System DB.xlsx")

# %%
df.head()
# Out:
#                                      Id  No  Barcode               Name  \
# 0  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52          قهوة تركي
# 1  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
# 2  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34  مياة معدنية صغيرة
# 3  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54       قهوة فرنساوي
# 4  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
#
#    PriceList                           Category_Id category_name  Quantity  \
# 0         35  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 1         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 2         10  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks         2
# 3         45  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 4         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         2
#
#    TotalPrice  Count  ...  SoldUnitName QuantityFromParentForSoldUnit  \
# 0        25.0      1  ...          قطعة                             1
# 1        65.0   1158  ...          قطعة                             1
# 2        20.0   1951  ...          قطعة                             1
# 3        45.0    816  ...          قطعة                             1
# 4       130.0   1128  ...          قطعة                             1
#
#    TotalCost UnitCost MenuId IsDone  DiscountValue            StartSession  \
# 0        0.0      0.0      1      1            0.0 2025-03-05 21:25:40.377
# 1        0.0      0.0      1      1            0.0 2025-05-18 11:50:57.397
# 2        9.0      4.5      1      1            0.0 2025-07-10 18:19:41.313
# 3        0.0      0.0      1      1            0.0 2025-04-30 09:04:09.887
# 4        0.0      0.0      1      1            0.0 2025-05-17 08:30:58.880
#
#              name_en category_name_en
# 0     Turkish coffee       Hot drinks
# 1  Nescafe with milk       Hot drinks
# 2        Small water      Cold drinks
# 3      French coffee       Hot drinks
# 4  Nescafe with milk       Hot drinks
#
# [5 rows x 37 columns]

# %%
df.head()
# Out:
#                                      Id  No  Barcode               Name  \
# 0  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52          قهوة تركي
# 1  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
# 2  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34  مياة معدنية صغيرة
# 3  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54       قهوة فرنساوي
# 4  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
#
#    PriceList                           Category_Id category_name  Quantity  \
# 0         35  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 1         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 2         10  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks         2
# 3         45  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 4         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         2
#
#    TotalPrice  Count  ...  SoldUnitName QuantityFromParentForSoldUnit  \
# 0        25.0      1  ...          قطعة                             1
# 1        65.0   1158  ...          قطعة                             1
# 2        20.0   1951  ...          قطعة                             1
# 3        45.0    816  ...          قطعة                             1
# 4       130.0   1128  ...          قطعة                             1
#
#    TotalCost UnitCost MenuId IsDone  DiscountValue            StartSession  \
# 0        0.0      0.0      1      1            0.0 2025-03-05 21:25:40.377
# 1        0.0      0.0      1      1            0.0 2025-05-18 11:50:57.397
# 2        9.0      4.5      1      1            0.0 2025-07-10 18:19:41.313
# 3        0.0      0.0      1      1            0.0 2025-04-30 09:04:09.887
# 4        0.0      0.0      1      1            0.0 2025-05-17 08:30:58.880
#
#              name_en category_name_en
# 0     Turkish coffee       Hot drinks
# 1  Nescafe with milk       Hot drinks
# 2        Small water      Cold drinks
# 3      French coffee       Hot drinks
# 4  Nescafe with milk       Hot drinks
#
# [5 rows x 37 columns]

# %%
df.to_excel("cave_eng.xlsx", index=False)

# %%
df.to_excel("F:/Work/Revelio/Cave Cafe/cave_eng.xlsx", index=False)

# %%
df.head()
# Out:
#                                      Id  No  Barcode               Name  \
# 0  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52          قهوة تركي
# 1  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
# 2  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34  مياة معدنية صغيرة
# 3  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54       قهوة فرنساوي
# 4  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
#
#    PriceList                           Category_Id category_name  Quantity  \
# 0         35  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 1         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 2         10  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks         2
# 3         45  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 4         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         2
#
#    TotalPrice  Count  ...  SoldUnitName QuantityFromParentForSoldUnit  \
# 0        25.0      1  ...          قطعة                             1
# 1        65.0   1158  ...          قطعة                             1
# 2        20.0   1951  ...          قطعة                             1
# 3        45.0    816  ...          قطعة                             1
# 4       130.0   1128  ...          قطعة                             1
#
#    TotalCost UnitCost MenuId IsDone  DiscountValue            StartSession  \
# 0        0.0      0.0      1      1            0.0 2025-03-05 21:25:40.377
# 1        0.0      0.0      1      1            0.0 2025-05-18 11:50:57.397
# 2        9.0      4.5      1      1            0.0 2025-07-10 18:19:41.313
# 3        0.0      0.0      1      1            0.0 2025-04-30 09:04:09.887
# 4        0.0      0.0      1      1            0.0 2025-05-17 08:30:58.880
#
#              name_en category_name_en
# 0     Turkish coffee       Hot drinks
# 1  Nescafe with milk       Hot drinks
# 2        Small water      Cold drinks
# 3      French coffee       Hot drinks
# 4  Nescafe with milk       Hot drinks
#
# [5 rows x 37 columns]

# %%
df.info('StartSession')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4781 entries, 0 to 4780
# Data columns (total 37 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Id                                4781 non-null   object
#  1   No                                4781 non-null   int64
#  2   Barcode                           4781 non-null   int64
#  3   Name                              4781 non-null   object
#  4   PriceList                         4781 non-null   int64
#  5   Category_Id                       4781 non-null   object
#  6   category_name                     4781 non-null   object
#  7   Quantity                          4781 non-null   int64
#  8   TotalPrice                        4781 non-null   float64
#  9   Count                             4781 non-null   int64
#  10  Client_Id                         0 non-null      float64
#  11  type                              4781 non-null   object
#  12  is_refund                         4781 non-null   int64
#  13  Session_Id                        4781 non-null   object
#  14  User_Id                           4781 non-null   object
#  15  SalaCaptinId                      4634 non-null   object
#  16  DeliveryManId                     0 non-null      float64
#  17  BranchId                          4781 non-null   int64
#  18  IsDeleted                         4781 non-null   int64
#  19  TableId                           4634 non-null   object
#  20  DailyCount                        4781 non-null   int64
#  21  YearCount                         4781 non-null   int64
#  22  Is_Cash                           4781 non-null   int64
#  23  Date                              4781 non-null   datetime64[ns]
#  24  UnitId                            4781 non-null   int64
#  25  ProductUnitName                   4781 non-null   object
#  26  QuantityFromParentForProductUnit  4781 non-null   int64
#  27  SoldUnitName                      4781 non-null   object
#  28  QuantityFromParentForSoldUnit     4781 non-null   int64
#  29  TotalCost                         4773 non-null   float64
#  30  UnitCost                          4773 non-null   float64
#  31  MenuId                            4781 non-null   int64
#  32  IsDone                            4781 non-null   int64
#  33  DiscountValue                     4781 non-null   float64
#  34  StartSession                      4781 non-null   datetime64[ns]
#  35  name_en                           4781 non-null   object
#  36  category_name_en                  4781 non-null   object
# dtypes: datetime64[ns](2), float64(6), int64(16), object(13)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Rush hour analysis

# %%
print(df['StartSession'].dtype)
# Out:
# datetime64[ns]

# %%
df['Month']=df['StartSession'].dt.month
df['week']=df['StartSession'].dt.isocalendar().week
df['day']=df['StartSession'].dt.day_name()
df['hour']=df['StartSession'].dt.hour

# %%
df.head()
# Out:
#                                      Id  No  Barcode               Name  \
# 0  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52          قهوة تركي
# 1  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
# 2  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34  مياة معدنية صغيرة
# 3  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54       قهوة فرنساوي
# 4  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
#
#    PriceList                           Category_Id category_name  Quantity  \
# 0         35  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 1         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 2         10  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks         2
# 3         45  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 4         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         2
#
#    TotalPrice  Count  ...  MenuId IsDone  DiscountValue  \
# 0        25.0      1  ...       1      1            0.0
# 1        65.0   1158  ...       1      1            0.0
# 2        20.0   1951  ...       1      1            0.0
# 3        45.0    816  ...       1      1            0.0
# 4       130.0   1128  ...       1      1            0.0
#
#              StartSession            name_en category_name_en  Month  week  \
# 0 2025-03-05 21:25:40.377     Turkish coffee       Hot drinks      3    10
# 1 2025-05-18 11:50:57.397  Nescafe with milk       Hot drinks      5    20
# 2 2025-07-10 18:19:41.313        Small water      Cold drinks      7    28
# 3 2025-04-30 09:04:09.887      French coffee       Hot drinks      4    18
# 4 2025-05-17 08:30:58.880  Nescafe with milk       Hot drinks      5    20
#
#          day hour
# 0  Wednesday   21
# 1     Sunday   11
# 2   Thursday   18
# 3  Wednesday    9
# 4   Saturday    8
#
# [5 rows x 41 columns]

# %%
def get_shift(hour):
    if 6 <= hour< 18:
        return 'Day Shift'
    else:
        return 'Night Shift'
df['Shift'] = df['hour'].apply(get_shift)

# %%
df.head()
# Out:
#                                      Id  No  Barcode               Name  \
# 0  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52          قهوة تركي
# 1  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
# 2  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34  مياة معدنية صغيرة
# 3  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54       قهوة فرنساوي
# 4  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36    نسكافية بالحليب
#
#    PriceList                           Category_Id category_name  Quantity  \
# 0         35  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 1         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 2         10  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks         2
# 3         45  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         1
# 4         65  a562390f-e36d-4349-aba5-99440975975c    Hot drinks         2
#
#    TotalPrice  Count  ...  IsDone DiscountValue            StartSession  \
# 0        25.0      1  ...       1           0.0 2025-03-05 21:25:40.377
# 1        65.0   1158  ...       1           0.0 2025-05-18 11:50:57.397
# 2        20.0   1951  ...       1           0.0 2025-07-10 18:19:41.313
# 3        45.0    816  ...       1           0.0 2025-04-30 09:04:09.887
# 4       130.0   1128  ...       1           0.0 2025-05-17 08:30:58.880
#
#              name_en category_name_en Month  week        day  hour  \
# 0     Turkish coffee       Hot drinks     3    10  Wednesday    21
# 1  Nescafe with milk       Hot drinks     5    20     Sunday    11
# 2        Small water      Cold drinks     7    28   Thursday    18
# 3      French coffee       Hot drinks     4    18  Wednesday     9
# 4  Nescafe with milk       Hot drinks     5    20   Saturday     8
#
#          Shift
# 0  Night Shift
# 1    Day Shift
# 2  Night Shift
# 3    Day Shift
# 4    Day Shift
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Plotting the Rush hour

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='hour', hue='Shift')
plt.title('Rush Hour Analysis by Shift')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Sessions')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='day', hue='Shift', order=['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])
plt.title('Rush days Analysis by Shift')
plt.xlabel('Days of the Week')
plt.ylabel('Number of Sessions')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.
plt.title('Rush Hour Analysis by Shift')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Sessions')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.timeplot(data=df, x='hour', hue='Shift', kind='count')
#       3 plt.title('Rush Hour Analysis by Shift')
#       4 plt.xlabel('Hour of Day')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'timeplot'

# %%
df = df.sort_values(by='StartSession')
df = df.sort_index()

# %%
df['StartSession']= pd.to_datetime(df['StartSession'])
df = df.set_index('StartSession')
session_per_day = df.resample('D').size()

# %%
plt.figure(figsize=(14,6))
session_per_day.plot()
plt.title('Number of Sessions per Day')
plt.xlabel('Date')
plt.ylabel('Number of Sessions')
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#                                                            Id  No  Barcode  \
# StartSession
# 2025-03-05 21:25:40.377  461bb8e3-fa25-4298-86d3-da3b3290f877  52       52
# 2025-05-18 11:50:57.397  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36
# 2025-07-10 18:19:41.313  94ab74f4-5224-4c87-8124-e92a15fd14dc  34       34
# 2025-04-30 09:04:09.887  6fe13d3e-ea5b-415f-81db-e9090dacb084  54       54
# 2025-05-17 08:30:58.880  daf19ef4-1eb3-49df-8ea1-0189c894eb76  36       36
#
#                                       Name  PriceList  \
# StartSession
# 2025-03-05 21:25:40.377          قهوة تركي         35
# 2025-05-18 11:50:57.397    نسكافية بالحليب         65
# 2025-07-10 18:19:41.313  مياة معدنية صغيرة         10
# 2025-04-30 09:04:09.887       قهوة فرنساوي         45
# 2025-05-17 08:30:58.880    نسكافية بالحليب         65
#
#                                                   Category_Id category_name  \
# StartSession
# 2025-03-05 21:25:40.377  a562390f-e36d-4349-aba5-99440975975c    Hot drinks
# 2025-05-18 11:50:57.397  a562390f-e36d-4349-aba5-99440975975c    Hot drinks
# 2025-07-10 18:19:41.313  2dc3d683-b099-4c3c-9df4-81935227e011   Cold drinks
# 2025-04-30 09:04:09.887  a562390f-e36d-4349-aba5-99440975975c    Hot drinks
# 2025-05-17 08:30:58.880  a562390f-e36d-4349-aba5-99440975975c    Hot drinks
#
#                          Quantity  TotalPrice  Count  ...  MenuId IsDone  \
# StartSession                                          ...
# 2025-03-05 21:25:40.377         1        25.0      1  ...       1      1
# 2025-05-18 11:50:57.397         1        65.0   1158  ...       1      1
# 2025-07-10 18:19:41.313         2        20.0   1951  ...       1      1
# 2025-04-30 09:04:09.887         1        45.0    816  ...       1      1
# 2025-05-17 08:30:58.880         2       130.0   1128  ...       1      1
#
#                          DiscountValue            name_en category_name_en  \
# StartSession
# 2025-03-05 21:25:40.377            0.0     Turkish coffee       Hot drinks
# 2025-05-18 11:50:57.397            0.0  Nescafe with milk       Hot drinks
# 2025-07-10 18:19:41.313            0.0        Small water      Cold drinks
# 2025-04-30 09:04:09.887            0.0      French coffee       Hot drinks
# 2025-05-17 08:30:58.880            0.0  Nescafe with milk       Hot drinks
#
#                         Month  week        day  hour        Shift
# StartSession
# 2025-03-05 21:25:40.377     3    10  Wednesday    21  Night Shift
# 2025-05-18 11:50:57.397     5    20     Sunday    11    Day Shift
# 2025-07-10 18:19:41.313     7    28   Thursday    18  Night Shift
# 2025-04-30 09:04:09.887     4    18  Wednesday     9    Day Shift
# 2025-05-17 08:30:58.880     5    20   Saturday     8    Day Shift
#
# [5 rows x 41 columns]

# %%
print(df.columns)
# Out:
# Index(['Id', 'No', 'Barcode', 'Name', 'PriceList', 'Category_Id',
#        'category_name', 'Quantity', 'TotalPrice', 'Count', 'Client_Id', 'type',
#        'is_refund', 'Session_Id', 'User_Id', 'SalaCaptinId', 'DeliveryManId',
#        'BranchId', 'IsDeleted', 'TableId', 'DailyCount', 'YearCount',
#        'Is_Cash', 'Date', 'UnitId', 'ProductUnitName',
#        'QuantityFromParentForProductUnit', 'SoldUnitName',
#        'QuantityFromParentForSoldUnit', 'TotalCost', 'UnitCost', 'MenuId',
#        'IsDone', 'DiscountValue', 'name_en', 'category_name_en', 'Month',
#        'week', 'day', 'hour', 'Shift'],
#       dtype='object')

# %%
top_months = df.groupby(['Month', 'hour']).size().reset_index(name='SessionCount')
top_months = top_months.sort_values(by='SessionCount', ascending=False)

# %%
top_months.head(10)
# Out:
#     Month  hour  SessionCount
# 27      5     8           580
# 14      4     8           493
# 15      4     9           235
# 6       3    18           219
# 5       3    17           176
# 42      6    12           175
# 40      6    10           168
# 30      5    11           113
# 12      4     3           104
# 28      5     9           103

# %%
pivot = top_months.pivot(index='hour', columns='Month', values='SessionCount')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Rush Hour Sessions by Month and Hour')
plt.xlabel('Month')
plt.ylabel('Hour of Day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 4
#       1 pivot = top_months.pivot(index='hour', columns='Month', values='SessionCount')
#       3 plt.figure(figsize=(12, 8))
# ----> 4 sns.heatmap(pivot, annot=True, fmt="d", cmap="YlGnBu")
#       5 plt.title('Rush Hour Sessions by Month and Hour')
#       6 plt.xlabel('Month')
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\seaborn\matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
plt.figure(figsize=(16, 8))
sns.barplot(data=top_months, x='hour', y='SessionCount', hue='Month')
plt.title('Rush Hour Sessions by Hour and Month')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Sessions')
plt.legend(title='Month')
plt.show()
